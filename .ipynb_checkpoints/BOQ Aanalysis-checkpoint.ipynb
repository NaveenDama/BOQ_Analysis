# %%
import pandas as pd

# %%
df = pd.read_excel("BOQ.xlsx")
df
# Out:
#            Qty                                        Description  \
# 0    4210.0000  Earth work excavation and depositing on bank (...
# 1     237.0000  Earth work excavation and depositing on bank (...
# 2    3000.0000  Earthwork excavation  in soil with hydraulic e...
# 3    2100.0000  Earthwork excavation in in ordinary rock with ...
# 4     402.9093  Earth work excavation for foundations for buil...
# ..         ...                                                ...
# 336     1.0000  FIRE ALARM CONTROL PANEL\nSupply, Installation...
# 337    15.0000  Manual Call point\nSupply and installation of ...
# 338    15.0000  Supply and fixing of addressable wall mounting...
# 339   450.0000  Cables\nSupply of 1.5sqmm FRLSH / HFFR PVC ins...
# 340   107.0000  SIGNAGES\nSupply and fixing of Escape signage ...
#
#                                               Long cat  \
# 0                                EARTH WORK EXCAVATION
# 1                                EARTH WORK EXCAVATION
# ...

# %%
df = df[~df['Amount'].isna()]

# %%
earth_work_filters = [['earthwork','excavation'],['earth work','excavation'],['filling','excavated'],['filling','gravel']]

# %%
df['category'] = ['']*len(df)
# Out:
# /var/folders/lr/krf7gnl93mq_9n0q7qnx4z_80000gn/T/ipykernel_1276/911945513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'] = ['']*len(df)

# %%
def get_category(description):
#     print(type(description))
    print(description[0][0])

    try:
        description = description.lower()

        for filter_list in earth_work_filters:
#             print(filter_list)
            keyword_len = len(filter_list)
            found_count = 0

            for keyword in filter_list:
                if(keyword in description):
                    found_count += 1
#             print("key found count:",found_count)
            
            if(found_count == keyword_len):
                return "Earth Work"
        return ""
    except:
        print("")
#         print("\n\nException:",description)

# %%
df.apply(get_category)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df.apply(get_category)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# ...
