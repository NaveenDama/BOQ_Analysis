# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# df = pd.read_excel("PG College BOQ.xls")
df = pd.read_excel("BOQ.xlsx")

df['category_keywords'] = ['not_filled']*len(df)
df['category'] = [' ']*len(df)
df = df[~df['Amount'].isna()]
df = df[~df['Description'].isna()]
df
# Out:
#            Qty                                        Description  \
# 0    4210.0000  Earth work excavation and depositing on bank (...
# 1     237.0000  Earth work excavation and depositing on bank (...
# 2    3000.0000  Earthwork excavation  in soil with hydraulic e...
# 3    2100.0000  Earthwork excavation in in ordinary rock with ...
# 4     402.9093  Earth work excavation for foundations for buil...
# ..         ...                                                ...
# 336     1.0000  FIRE ALARM CONTROL PANEL\nSupply, Installation...
# 337    15.0000  Manual Call point\nSupply and installation of ...
# 338    15.0000  Supply and fixing of addressable wall mounting...
# 339   450.0000  Cables\nSupply of 1.5sqmm FRLSH / HFFR PVC ins...
# 340   107.0000  SIGNAGES\nSupply and fixing of Escape signage ...
#
#                                               Long cat  \
# 0                                EARTH WORK EXCAVATION
# 1                                EARTH WORK EXCAVATION
# 2                                       EARTH WORK SDR
# 3                             EARTH WORK Ordinary rock
# 4                                 EARTH WORK Hard rock
# ..                                                 ...
# 336  Supply, Installation, testing and commissionin...
# 337  Supply and installation of addressable analogu...
# 338  Supply and fixing of addressable wall mounting...
# 339  Supply and laying of 1.5 Sq.mm 2 Core PVC / XL...
# 340         Supply and fixing of Escape signage boards
#
#                                              Short cat  \
# 0                                EARTH WORK EXCAVATION
# 1                                EARTH WORK EXCAVATION
# 2                                       EARTH WORK SDR
# 3                             EARTH WORK Ordinary rock
# 4                                 EARTH WORK Hard rock
# ..                                                 ...
# 336  Supply, Installation, testing and commissionin...
# 337  Supply and installation of addressable analogu...
# 338  Supply and fixing of addressable wall mounting...
# 339  Supply and laying of 1.5 Sq.mm 2 Core PVC / XL...
# 340         Supply and fixing of Escape signage boards
#
#                                    Code       Rate      Unit     Amount  \
# 0                                   308     526.90     1 Cum  2218249.0
# 1                                   308     301.10     1 Cum    71361.0
# 2                             Morth 301     134.25     1 Cum   402750.0
# 3                             Morth 301     171.80     1 Cum   360780.0
# 4                          APSS No. 308    2588.25     1 Cum  1042830.0
# ..                                  ...        ...       ...        ...
# 336  AS directed By Engineer  In charge  326643.00    ONE No   326643.0
# 337  AS directed By Engineer  In charge    4550.00   ONE No.    68250.0
# 338  AS directed By Engineer  In charge    4233.00   ONE No.    63495.0
# 339  AS directed By Engineer  In charge      25.00  ONE Rmts    11250.0
# 340  AS directed By Engineer  In charge    1516.00    ONE No   162212.0
#
#     category_keywords category
# 0          not_filled
# 1          not_filled
# 2          not_filled
# 3          not_filled
# 4          not_filled
# ..                ...      ...
# 336        not_filled
# 337        not_filled
# 338        not_filled
# 339        not_filled
# 340        not_filled
#
# [337 rows x 10 columns]

# %%
earth_work_filters = ['Earth Work',['rock'],['earthwork','excavation'],['earth work','excavation'],
                      ['filling','excavated'],['filling','gravel'],
                      ['filling','sand'],['filling','metal']
                     ]
concrete_filters = ['Concrete',
                    ['plain','cement','concrete'],['vibrated','reinforced','cement','concrete'],
                    ['reinforced','cement','concrete'],['vibrated','cement','concrete'],
                    ['cinder','concrete']
                   ]
steel_filters = ['Steel',['steel','fe 500']]
brick_masonry_filters = ['Brick Masonry',['brick masonry']]
plastering_filters = ['Plastering',['plastering'],['impervious']]
painting_filters = ['Painting',['painting']]
flooring_filters = ['Flooring',['flooring'],['skirting'],['dadooing'],['granite']]
door_filters = ['Doors',['door','leaf','shutter'],['door','wood'],['polish','wood']]
window_filters = ['Windows',['window']]
ventilator_filters = ['Ventilators',['ventilator']]
sanitary_filters = ['Sanitary',
                    ['cpvc','pipe'],['soap','dish'],['manhole'],['inspection chamber'],
                    ['swg','pipe'],['gully','trap'],['floor','trap'],['orissa','pan'],
                    ['water','closet'],['urinal'],['wash','basin'],['health','faucet'],
                    ['vitreous'],['brass','tap'],
                    ['swr','pvc'],['ball','valve','din'],['wall','mixer'],['polyethylene','water','tank'],
                    ['mirror'],['towel','rod'],['pvc','rain']
                   ]
electrical_filters = ['Electrical',['wire'],['wiring'],['fire'],['alaram'],['earthing'],['electrical'],
                      ['electronic'],['cord'],['motor'],
                      ['cable'],['copper'],['frls'],['fan'],['copper cable'],
                      ['switch'],['pvc','frls'],['fan','hook'],['modular','switch'],
                      ['modular','box'],['phase','neutral'],['3 phase'],['distribution','board'],
                      ['mcb'],['single','phase'],['g.i','strip' ],['led','light'],['led','power'],
                      ['batten'],['ding','dong'],['patch'],['net','work'],['network'],['pole','erection'],
                      ['valve'],['hydrant'],['honeywell']
                     ]
steel_work_filters = ['Steel Work',['steel'],['aluminium'],['roofing'],['ms','gate']]
wood_work_filters = ['Wood Work',['wood']]

# %%
def apply_filter(description,given_filter):
    category = given_filter[0]
    for filter_list in given_filter[1:]:
#             print(filter_list)
        keyword_len = len(filter_list)
        found_count = 0
        
        for keyword in filter_list:
            if(keyword in description):
                found_count += 1
#             print("key found count:",found_count)

        if(found_count == keyword_len):
#             print(filter_list)
            return category+"   "+"["+','.join(filter_list)+"]"
    return "not_filled"

# %%
def get_category(row,*filters):
#     print(filters)
#     print(type(description))
  
        if(row['category_keywords'] == "not_filled"):

                description = row['Description'].lower()
                return apply_filter(description,filters)
        else:
            return row['category_keywords']

# %%
df['category_keywords'] = df.apply(get_category,axis=1,args=concrete_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=steel_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=ventilator_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=window_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=sanitary_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=brick_masonry_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=plastering_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=painting_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=flooring_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=door_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=electrical_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=earth_work_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=steel_work_filters)
df['category_keywords'] = df.apply(get_category,axis=1,args=wood_work_filters)
df['category_keywords'].value_counts()
# Out:
# Concrete   [vibrated,reinforced,cement,concrete]    32
# Flooring   [flooring]                               27
# Electrical   [cable]                                23
# Plastering   [plastering]                           21
# Electrical   [wire]                                 18
#                                                     ..
# Sanitary   [wall,mixer]                              1
# Sanitary   [soap,dish]                               1
# Sanitary   [wash,basin]                              1
# Sanitary   [mirror]                                  1
# Electrical   [honeywell]                             1
# Name: category_keywords, Length: 72, dtype: int64

# %%
df[df['category'] == 'Painting']
# Out:
# Empty DataFrame
# Columns: [Qty, Description, Long cat, Short cat, Code, Rate, Unit, Amount, category_keywords, category]
# Index: []

# %%
df['category'] = df['category_keywords'].apply(lambda x : x.split('[')[0].strip())
df['category'].value_counts()
# Out:
# Electrical       102
# Concrete          65
# Flooring          43
# Sanitary          32
# Plastering        29
# not_filled        11
# Painting          11
# Brick Masonry      9
# Doors              9
# Earth Work         8
# Steel Work         8
# Steel              5
# Ventilators        3
# Windows            1
# Wood Work          1
# Name: category, dtype: int64

# %%
len(sqm_df)
# Out:
# 29

# %%
sqm_df = df[(df['category'] == 'Concrete')& (df['Unit'].apply(lambda x : 'sqm' in x.lower())) ]

count = 0
sums = 0
for i in range(len(sqm_df)):
    
    
    if("slab" not in sqm_df.iloc[i]['Description'].lower() ):
        print("\n\n")
        count+=1
        print(sqm_df.iloc[i]['Description'])
        sums += sqm_df.iloc[i]['Amount']
print(count)
# Out:
# Vibrated Reinforced Cement Concrete  M 25 Design Mix ( by weigh batching / Mixer  ) using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS5)  hard blasted Trap crushed graded metal (Coarse aggregate) from approved quarry, using a minimum quantity of 380 kgs. of cement per 1 cum of concreteincluding cost and conveyance of  all materials  like cement,  fine aggregate (Sand), coarse aggregate, water etc., to site and cost of  all materials including centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering , machine mixing, laying concrete, vibrating,lift charges, curing etc., complete but excluding cost of steel and it’s fabrication charges but excluding seigniorage charges for finished item of work (APSS No. 402 & 403)
#
#
#
# Vibrated Reinforced Cement Concrete  M 25 Design Mix ( by weigh batching / Mixer  ) using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS5)  hard blasted Trap crushed graded metal (Coarse aggregate) from approved quarry, using a minimum quantity of 380 kgs. of cement per 1 cum of concreteincluding cost and conveyance of  all materials  like cement,  fine aggregate (Sand), coarse aggregate, water etc., to site and cost of  all materials including centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering , machine mixing, laying concrete, vibrating,lift charges, curing etc., complete but excluding cost of steel and it’s fabrication charges but excluding seigniorage charges for finished item of work (APSS No. 402 & 403)
#
#
#
# Vibrated Reinforced Cement Concrete  M 25 Design Mix ( by weigh batching / Mixer  ) using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS5)  hard blasted Trap crushed graded metal (Coarse aggregate) from approved quarry, using a minimum quantity of 380 kgs. of cement per 1 cum of concreteincluding cost and conveyance of  all materials  like cement,  fine aggregate (Sand), coarse aggregate, water etc., to site and cost of  all materials including centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering , machine mixing, laying concrete, vibrating,lift charges, curing etc., complete but excluding cost of steel and it’s fabrication charges but excluding seigniorage charges for finished item of work (APSS No. 402 & 403)
#
#
#
# Vibrated Reinforced Cement Concrete  M 25 Design Mix ( by weigh batching / Mixer  ) using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS5)  hard blasted Trap crushed graded metal (Coarse aggregate) from approved quarry, using a minimum quantity of 380 kgs. of cement per 1 cum of concreteincluding cost and conveyance of  all materials  like cement,  fine aggregate (Sand), coarse aggregate, water etc., to site and cost of  all materials including centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering , machine mixing, laying concrete, vibrating,lift charges, curing etc., complete but excluding cost of steel and it’s fabrication charges but excluding seigniorage charges for finished item of work (APSS No. 402 & 403)
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS 5) machine crushed hard blasted Trap graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering, machine mixing, laying  concrete, for sunshade of 7.5cm thick  at  fixed end  and 5cm thick at free end  with  an average  thickness of  6.25cm   including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of workSunshades- Ground Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS 5) machine crushed hard blasted Trap graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering, machine mixing, laying  concrete, for sunshade of 7.5cm thick  at  fixed end  and 5cm thick at free end  with  an average  thickness of  6.25cm   including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of workSunshades- First Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS 5) machine crushed hard blasted Trap graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering, machine mixing, laying  concrete, for sunshade of 7.5cm thick  at  fixed end  and 5cm thick at free end  with  an average  thickness of  6.25cm   including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of workSunshades- Second Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS 5) machine crushed hard blasted Trap graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering, machine mixing, laying  concrete, for sunshade of 7.5cm thick  at  fixed end  and 5cm thick at free end  with  an average  thickness of  6.25cm   including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of workSunshades- Third Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using Manufactured Sand (Rock sand) and natural river sand in the ratio of 50:50, 20mm size (SS 5) machine crushed hard blasted Trap graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using  Steel scaffolding pipes, jack Props, wallers, Foot plates, brackets, steel Centering Plates,etc., shuttering, machine mixing, laying  concrete, for sunshade of 7.5cm thick  at  fixed end  and 5cm thick at free end  with  an average  thickness of  6.25cm   including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of workSunshades- Fourth Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Racks and Shelves 40mm thick  -Ground Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Racks and Shelves 40mm thick  -First Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Racks and Shelves 40mm thick  Second floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Racks and Shelves 40mm thick  -Third floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Platforms 75mm thick  -Ground Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Platforms 75mm thick  -First Floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Platforms 75mm thick  -Second floor
#
#
#
# Reinforced cement concrete with M 20 grade Design mix ( by weigh batching )  using 20mm size (SS 5) machine crushed hard blasted granite graded metal (coarse  aggregate)  from approved  quarry using a minimum quantity of 350 Kg of cement per 1 Cum of concrete including cost and conveyance of all materials like cement, fine aggregate (sand) ,coarse  aggregate, water  etc.  to site  and cost of    all  materials   including  centering using Cashewrina Ballies and Wooden runners & staging including all bracings, cross members etc.,  shuttering, machine mixing, laying  concrete, including   labour  charges   for mixing,  laying, curing  etc.,  complete but  excluding cost of  steel  and  its fabrication charges but excluding seigniorage charges for finished item of work. Platforms 75mm thick  -Third Floor
# 17

# %%
df[df['category'] == 'not_filled'].iloc[:50]
# Out:
#         Qty                                        Description  \
# 7    4800.0  Construction of embankment with approved mater...
# 8    1360.0  Construction of embankment with material obtai...
# 159    96.0  Supplying & fixing of pre-cast RCC Grills of a...
# 175    38.0  Providing and Fixing of expansion joint filler...
# 185   414.0  Forming embankment with Side earth by mechanic...
# 186   559.0  Construction of Gravel shoulders  including co...
# 190   195.0  Fixing of Brick on edge around the play fields...
# 191    16.0  Providing and fixing GI pipes of Nominal bore ...
# 194    25.0  Supplying , laying , aligning & jointing of RC...
# 292    15.0  Fabrication, Transportation and supply of 1.50...
# 302     1.0  Providing transformer plinth 1.2 x 1.2 x 1.5 m...
#
#                                               Long cat  \
# 7                         Embankment – deposited soils
# 8                             Embankment – barrow pits
# 159                                         RCC grills
# 175                                       Filler board
# 185                                         Embankment
# 186                                   Gravel shoulders
# 190                                      Brick on edge
# 191                                            GI pipe
# 194                                          Hume pipe
# 292  Fabrication, Transportation and supply of  of ...
# 302   Providing transformer plinth 1.2 x 1.2 x 1.5 mtr
#
#                                              Short cat  \
# 7                         Embankment – deposited soils
# 8                             Embankment – barrow pits
# 159                                         RCC grills
# 175                                       Filler board
# 185                                         Embankment
# 186                                   Gravel shoulders
# 190                                      Brick on edge
# 191                                            GI pipe
# 194                                          Hume pipe
# 292  Fabrication, Transportation and supply of  of ...
# 302   Providing transformer plinth 1.2 x 1.2 x 1.5 mtr
#
#                                            Code      Rate   Unit    Amount  \
# 7                                           305    164.20  1 Cum  788160.0
# 8                                           305    395.95  1 Cum  538492.0
# 159  as directed  \n By Engineer    \nIn charge    729.00   1SQM   69984.0
# 175  as directed  \n By Engineer    \nIn charge    465.85  1 Sqm   17702.0
# 185                                   Morth 305    217.00  1 cum   89838.0
# 186                             Morth 401 & 407    945.00  1 cum  528255.0
# 190          AS directed By Engineer  In charge    162.65  1 Rmt   31717.0
# 191          AS directed By Engineer  In charge    655.40  1 Rmt   10486.0
# 194          AS directed By Engineer  In charge   1014.00  1 Rmt   25350.0
# 292          AS directed By Engineer  In charge   2154.00   EACH   32310.0
# 302          AS directed By Engineer  In charge  19728.00   EACH   19728.0
#
#     category_keywords    category
# 7          not_filled  not_filled
# 8          not_filled  not_filled
# 159        not_filled  not_filled
# 175        not_filled  not_filled
# 185        not_filled  not_filled
# 186        not_filled  not_filled
# 190        not_filled  not_filled
# 191        not_filled  not_filled
# 194        not_filled  not_filled
# 292        not_filled  not_filled
# 302        not_filled  not_filled

# %%
segment_wise_df = df.groupby('category').agg({'Amount':['sum']})
segment_wise_df.reset_index(inplace=True)
segment_wise_df.columns = ["Category","Amount"]
segment_wise_df['percentage'] = round((segment_wise_df['Amount']/sum(segment_wise_df['Amount']))*100,2)
segment_wise_df.sort_values('Amount',ascending=False,inplace=True)
segment_wise_df.reset_index(inplace=True,drop=True)
segment_wise_df['Cumilative Percentage'] = segment_wise_df['percentage'].cumsum()
segment_wise_df
# Out:
#          Category      Amount  percentage  Cumilative Percentage
# 0        Concrete  71259924.0       25.71                  25.71
# 1           Steel  50976540.0       18.39                  44.10
# 2      Plastering  36127779.0       13.04                  57.14
# 3   Brick Masonry  28842357.0       10.41                  67.55
# 4        Flooring  27865834.0       10.05                  77.60
# 5      Electrical  18987842.0        6.85                  84.45
# 6        Painting  12275352.0        4.43                  88.88
# 7         Windows   7349874.0        2.65                  91.53
# 8       Wood Work   5186700.0        1.87                  93.40
# 9      Earth Work   4398917.0        1.59                  94.99
# 10       Sanitary   4361399.0        1.57                  96.56
# 11          Doors   3504837.0        1.26                  97.82
# 12     Steel Work   2471554.0        0.89                  98.71
# 13     not_filled   2152022.0        0.78                  99.49
# 14    Ventilators   1376307.0        0.50                  99.99

# %%
segment_wise_df['Category'].to_list()
# Out:
# ['Concrete',
#  'Steel',
#  'Plastering',
#  'Brick Masonry',
#  'Flooring',
#  'Electrical',
#  'Painting',
#  'Windows',
#  'Wood Work',
#  'Earth Work',
#  'Sanitary',
#  'Doors',
#  'Steel Work',
#  'not_filled',
#  'Ventilators']

# %%
narayana_categories = ['Concrete',
 'Plastering',
 'Brick Masonry',
 'Steel',
]

# %%
narayana_mask = segment_wise_df['Category'].apply(lambda x : x in narayana_categories)
narayana_df = segment_wise_df[narayana_mask]
print("Toatl Work Value:",sum(segment_wise_df['Amount']))
print("Narayana Work Value:",sum(narayana_df['Amount']))
print("Narayana Work Percentage:",round(sum(narayana_df['Amount'])*100/sum(segment_wise_df['Amount']),2))
narayana_df['percentage'] = round((narayana_df['Amount']/sum(narayana_df['Amount']))*100,2)
narayana_df['Cumilative Percentage'] = narayana_df['percentage'].cumsum()
narayana_df
# Out:
# Toatl Work Value: 277137238.0
# Narayana Work Value: 187206600.0
# Narayana Work Percentage: 67.55
#         Category      Amount  percentage  Cumilative Percentage
# 0       Concrete  71259924.0       38.06                  38.06
# 1          Steel  50976540.0       27.23                  65.29
# 2     Plastering  36127779.0       19.30                  84.59
# 3  Brick Masonry  28842357.0       15.41                 100.00

# %%
df['sub_category'] = ['not_filled']*len(df)

# %%
df[df['category'] == 'Sanitary']['Description'].value_counts()
# Out:
# BALL VALVE\nSupply, installation, testing and commissioning of 25mm dia Ball valve and  as per approval make and as directed by engineer-in-charge and including transportation and labour charges\nMakes : Zoloto / Leader / Honeywell                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2
# Supply and fixing of 110mm dia ISI mark PVC rain water spouts of 4 Kg/cm2 pressure including Cost of necessary pvc bends, shoes and M.S.clamps  and all other accessories and fixing in position including cost and conveyance of all materials to site , seigniorage charges sales and other taxes on all materials, all operational, incidental and labour cahrges such as fixing in alignment etc., complete for finished item of work.(APSS NO1328) in All Floors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Supply and fixing of Ashirvad/Ajay/Astral Flowgaurd or equivalent CPVC pipes and fittings to meet the requirement of ASTM-D 2846 and are produced in CTS( copper tube sizes 1/4" to 2" ) ashirwad flowgaurd SDR11 and SDR 13.5 pipes are made from identical CPVC components having the same physical properties for Hot and cold Water confirming to  (IS 15778-2007)15.90mm OD pipe                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Providing & Placing on Terrace (at all floor levels) polyethylene water storage tank with Double layer approved brand & manufacture with cover and suitable locking arrangement & making necessary holes for inlet & outlets and over flow pipes but without fittings & base support for tanks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Supply, Fabrication, Transportation and erection of DP structure made with 2 Nos 175mm x 85mm ( ISMB Modified ) or equivalent about 30'-0 length / 9.1 mtrs length RS joist pole erection of the same Including excavation of pit in all kinds of soil including breaking stones, concreting with (1:3:6) mixture base plate, coil earthing back filling, 1:2:4 for couping including red oxide primary painting and two coats of aluminium painting etc., complete as required with following as per CEIG norms.\na). 400A AB Switch-1No\nb) HG Fuse sets-1No\nc). LAS-1set.\nd) Required Number of 11KV pin and disc Insulatiors.\ne) Required length of 100X50mm and 75X40 mm ISMC chanell iron including two coats of redoxide and two coats of enamil paint ect for finished item of work.\nf) 11KV pin insulators and disc insulators.\ng) AB switch operating pipe with handle and lock and key arrangements.\nh). "0" SWG or 8.25 mm dia hard drawn bare copper wire including copper binding wire etc., complete as required including connections.\ni) 40X6mm GI strip for the DP structure earthing.\nj) 25X6mm copper strip for lightning arrestors earthing.\nk) 600X600mmX3,15mm thick copperplate earthings as per NEC with brick massonary chambers - 2 Nos\nl) GI pipe earthing for the Double pole structure with brick massonry chambers as per IS - 2 Nos    1
# Labour charges for run of U.G cable on wall / existing pipe with necessary fixing arrangments such as saddles, clamps,wooden separators etc., (as directed by departmental official) with No.10 SWG G.I wire for eath connections for the cables.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# Supplying and fixing PPR ball  valve of 25 mm dia confirming to DIN standards 8077/8092 , Indian make heavy type including cost and conveyance of all materials , labour charges etc. complete for finished item of work.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Supplying and fixing PPR ball  valve of 32 mm dia confirming to DIN standards 8077/8092 , Indian make heavy type including cost and conveyance of all materials , labour charges etc. complete for finished item of work.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Supplying and fixing of SWR/ PVC pipes (as per ISI standards) 4 Kg/Sq.cm. Prince/sudhakar or any ISI brand and fixing all special such as plain bends, off sets, door bends, single junctions, double junctions as per site requirement, fixing with PVC clamps if necessary with required number of Bombay nails including cost and conveyance of all materials to site, labour charges etc.complete for finished item of work at all floor levels. (APSS No. 1302  1319 & 1326)110 mm dia                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# Supplying and fixing of SWR/ PVC pipes (as per ISI standards) 4 Kg/Sq.cm. Prince/sudhakar or any ISI brand and fixing all special such as plain bends, off sets, door bends, single junctions, double junctions as per site requirement, fixing with PVC clamps if necessary with required number of Bombay nails including cost and conveyance of all materials to site, labour charges etc.complete for finished item of work at all floor levels. (APSS No. 1302  1319 & 1326)75mm dia                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Supply and fixing of Ashirvad/Ajay/Astral Flowgaurd or equivalent CPVC pipes and fittings to meet the requirement of ASTM-D 2846 and are produced in CTS( copper tube sizes 1/4" to 2" ) ashirwad flowgaurd SDR11 and SDR 13.5 pipes are made from identical CPVC components having the same physical properties for Hot and cold Water confirming to  (IS 15778-2007)54.20 mm OD pipe                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Supply and fixing of Ashirvad/Ajay/Astral Flowgaurd or equivalent CPVC pipes and fittings to meet the requirement of ASTM-D 2846 and are produced in CTS( copper tube sizes 1/4" to 2" ) ashirwad flowgaurd SDR11 and SDR 13.5 pipes are made from identical CPVC components having the same physical properties for Hot and cold Water confirming to  (IS 15778-2007)41.30mm OD pipe                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Supply and fixing of Ashirvad/Ajay/Astral Flowgaurd or equivalent CPVC pipes and fittings to meet the requirement of ASTM-D 2846 and are produced in CTS( copper tube sizes 1/4" to 2" ) ashirwad flowgaurd SDR11 and SDR 13.5 pipes are made from identical CPVC components having the same physical properties for Hot and cold Water confirming to  (IS 15778-2007)34.90mm OD pipe                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Supply and fixing of Ashirvad/Ajay/Astral Flowgaurd or equivalent CPVC pipes and fittings to meet the requirement of ASTM-D 2846 and are produced in CTS( copper tube sizes 1/4" to 2" ) ashirwad flowgaurd SDR11 and SDR 13.5 pipes are made from identical CPVC components having the same physical properties for Hot and cold Water confirming to  (IS 15778-2007)28.60mm OD pipe(Domestic water)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Supply and fixing of Ashirvad/Ajay/Astral Flowgaurd or equivalent CPVC pipes and fittings to meet the requirement of ASTM-D 2846 and are produced in CTS( copper tube sizes 1/4" to 2" ) ashirwad flowgaurd SDR11 and SDR 13.5 pipes are made from identical CPVC components having the same physical properties for Hot and cold Water confirming to  (IS 15778-2007)22.20mm OD pipe(Domestic water)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Supplying and fixing of 15 mm brass body CP finish bib tap of not less than 300 grams weight screw type (full turn) with internal /external threaded conenction conforming to IS 8931 including cost and conveyance of all materials, labour charges etc., complete for finished item of work in all floors.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Supplying and laying, filling, jointing and testing SWG SP-1 pipes  of ISI make confirming to IS 1651 & 4127 1st quality with air tight Cement joints in CM (1.5:1)prop. including excavation of trenches and socket pits in any soil  (except rock requiring blasting)  and refilling with watering and tamping  including cost and conveyance of all materials to site and all labour charges for finished item of work (APSS NO 1301 & 1318)152.40mm dia SWG pipe upto 3' depth                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Supplying and fixing TV shape mirror with plastic frame of size 609.6mm x 457.2mm , plywood back with NP screws 1st quality including cost and conveyance of all materials, labour charges etc., complete for finished item of work in all floors.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Supplying and fixing Indian make  Flat Back Wash Hand Basin (HSW/Parryware/ Neycer) 1st quality conforming to IS:2556-Part-4:1972 of size 550mm x 400mm with waste fittings like rubber plug, chain,  32 mm nominal size C.P. Fitting with parallel pipe thread conforming to IS:2963-1979 and fitted with 15 mm nominal bore Chromium Plated Pillar Tap of 1st quality Indian make 400 grams Seiko/ Esso or equivalent complete with standard CI brackets including wooden block ,1 No.12.70mm PVC connection with brass union nuts CP coated , 1 No.12.70mm NP bib tap 300 gms Seiko or equivalent including cost and conveyance of all materials to site, labour charges etc. complete for finished item of work                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Supplying and fixing CP finish brass soap dish type complete including cost and conveyance of all materials, labour charges for fixing etc., complete for finished item of work in all floors as per ssr item no 598                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# S&F of 15 mm CP finish brass body wall mixer conforming to IS 8931 with center distance 150 mm conforming to IS 8931 and fixing of  15 mm nominal size Chromium plated finish brass over head shower arm of 450 mm long with 90 degree bend & wall flange suitable for rain shower and with 10 years warranty                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Supplying and fixing of 16mm to 18 mm thick High polished Granite slab partitioins of 1st quality fixed in wall for urinals portion, including cost and conveyance of all materials, labour charges etc., complete for finished item of work of size (0.90x0.50mts)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Supplying & Fixing white glazed flat back half stall urinals 1st quality conforming to IS:2556-1995 with standard C.P. Spreader fixed with screws complete Indian make : 410 x 265 x 305 mm  (HS W/Parry/Neycer) conforming to IS 2556 -1995 as approved be Engineer - in - charge 12.7 mm PVC connection with brass plumber union nuts CM Coated. including 12.70 mm push cock 1st qulaity of approved make including supply & fixing 31.75 m dia PVC flexible waser pipe of 914.40 mm lenght of 1st including cost and conveyance of all materials to site labour charges etc., complete for finished item of work for all floors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Supplying and fixing approved make wash down European Water Closet of 1st quality conforming to IS:2556-Part-2-2004 of white glazed with 'S' trap,supplying and fixing  best Indian make plastic seat and lid for European water closets with rubber or plastic Buffers as per IS 2548-1996  and 10 litres capacity single flush PVC  low level cistern with internal components and fixed using required size of nails and screws, 15 mm brass angle stop valve of quarter turn spindle type of not less than 400 grams weight with internal threaded conforming to IS 8931, 15mm PVC connections with brass union nuts CP coated including cost and conveyance of all materials to site, overheads & contractors profit etc., complete  for finished item of work for all floors.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Supplying and fixing 580 mm x 440 mm long Orissa pan white glazed Water Closet 1st qualityISI marked confirming to IS:2556-Part-3-1981 with "P" or "S" trap Hindware / Parryware / Neycer with brick masonry seat, CC squatting plate and fixing 12.70mm dia NP Push cock 1st quality ,  P trap or S trap of Indian W.C. shall be encased on CC (1:2:4) 150mm alround well above the joint to stop leakage at the joint etc., complete including cost and conveyance of all materials to site, cost of CC bed, labour charges and seigniorage charges etc., complete for finished item of work.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Supplying and fixing of 4" (101.6mm) multi floor trap with jali - UPVC/SWR pipe fittings as per site requirements with standard practice  for all floors including cost and conveyance of all materials to site, labour charges , overheads & contractors profit etc., complete for finished item of work.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# Constructing 904.0 mm (3’0”) dia solid block masonry  inspection chamber as per IS - 4111: Part-1:1986 with cement mortar (1:6) prop using fly ash blocks of 225mm thick from approved source having a minimum crushing strength of 10 N/sq.mm  including plastering with cement mortar 1:3 prop; ½” thick both inside and outside fitted with 20” dia RCC manhole covers and frames including excavating pits up to a depth of 1524 mm (5'-0") in all sorts of soils (exculding rock) and laying cement conrete (1:4:8) 150 mm thick using 40 mm HBG Metal and P.C.C. 1:2:4 benching and channel 100 mm thick as per Standard specification and  including cost and conveyance of all materials like cement, sand, bricks, water etc., to site, cost of seigniorage charges on all materials and all incidental and  operational, labour charges like mixing cement mortar, constructing masonry, lift charges, curing etc., complete for finished item of work as per Standard specification.                                                                                                                                                                                                                                                                                                                                                                                  1
# Constructing 904.0 mm (3’0”) dia brick masonry inspection chamber as per IS - 4111: Part-1:1986 with cement mortar (1:6) prop using 2nd Class Clay Bricks of 225 mm thick from approved source having a minimum crushing strength of 5 N/sq.mm  including plastering with cement mortar 1:3 prop; ½” thick both inside and outside fitted with 20” dia RCC manhole covers and frames including excavating pits up to a depth of 904 mm (3'-0") in all sorts of soils (exculding rock) and laying cement conrete (1:4:8) 150 mm thick using 40 mm HBG Metal and P.C.C. 1:2:4 benching and channel 100 mm thick as per Standard specification and  including cost and conveyance of all materials like cement, sand, bricks, water etc., to site, cost of seigniorage charges on all materials and all incidental and  operational, labour charges like mixing cement mortar, constructing masonry, lift charges, curing etc., complete for finished item of work as per Standard specification.                                                                                                                                                                                                                                                                                                                                                                                   1
# Constructing 457.2mm x 457.2mm (1'-6" x 1'-6") brick in CM (1:6) prop. Masonry inspection chamber upto 914.4mm (3'-0") and fitted with light weight 457.2mm x 457.2mm (1'-6" x 1"-6") frame and cover of 20kg., including cost and convenyance of all materials to site, all labour charges, sales and otehr taxes on all materials etc., complete for finished item of work                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Supplying and fixing 150.00mmx100.00mm SWG  gully trap 1st class confirming to  ISI 651 & 4127 with CI grating and constructing single brick masonry wall chamber of size 20" x 14" x 12” in CM (1:6) prop. Over a CC (1:5:10)prop. bed, and fitted with 304.8 mm x 225.6 mm(12" x 9") CI frame and hinged cover  and plastering 12mm thk. in CM (1:4) prop. both inside and outside surfaces and including cost and conveyance of all materials to site, labour charges etc., complete for finished item of work.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# Supplyand fixing of hose cabinet of size 750mm X 600mm x 250mm made of No 16 gauge SWG CRCA sheet with 6mm thick glazed glass door including necessary locking arrangement suitable to accommodate 2 Nos 15 mtr long Hose pipe, 1 No branch pipe, mounted on wall OR raised brick platform and duly painted with Post office red externally and white internally with synthetic enamel paint complete in all respect, for external hydrant as required and  as per approval make and as directed by engineer-in-charge and including transportation and labour charges\nMake: Mini Max / Safex / Newage / Winco / Newtech / Padmini.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Name: Description, dtype: int64

# %%
sanitary_filters = ['Sanitary',
                    ['cpvc','pipe'],['soap','dish'],['manhole'],['inspection chamber'],
                    ['swg','pipe'],['gully','trap'],['floor','trap'],['orissa','pan'],
                    ['water','closet'],['urinal'],['wash','basin'],['health','faucet'],
                    ['vitreous'],['brass','tap'],
                    ['swr','pvc'],['ball','valve','din'],['wall','mixer'],['polyethylene','water','tank'],
                    ['mirror'],['towel','rod'],['pvc','rain']
                   ]
electrical_filters = ['Electrical',['wire'],['wiring'],['fire'],['alaram'],['earthing'],['electrical'],
                      ['electronic'],['cord'],['motor'],
                      ['cable'],['copper'],['frls'],['fan'],['copper cable'],
                      ['switch'],['pvc','frls'],['fan','hook'],['modular','switch'],
                      ['modular','box'],['phase','neutral'],['3 phase'],['distribution','board'],
                      ['mcb'],['single','phase'],['g.i','strip' ],['led','light'],['led','power'],
                      ['batten'],['ding','dong'],['patch'],['net','work'],['network'],['pole','erection'],
                      ['valve'],['hydrant'],['honeywell']
                     ]
steel_work_filters = ['Steel Work',['steel'],['aluminium'],['roofing'],['ms','gate']]
wood_work_filters = ['Wood Work',['wood']]

# %%
concrete_sub_filters = {
    ('plain', 'cement', 'concrete'): 'PCC',
 ('vibrated', 'reinforced', 'cement', 'concrete'):'VRCC', 
 ('reinforced', 'cement', 'concrete'):'RCC',
 ('vibrated', 'cement', 'concrete'):'VCC',
 ('cinder', 'concrete'):'Cinder Concrete'
}


steel_sub_filters = {
    ('steel', 'fe 500'):'Steel'
}

brick_masonry_sub_filters = {
    ('fly', 'ash') : 'Fly Ash Bricks',
    ('autoclaved','aerated','concrete') : 'AAC'
}

plastering_sub_filters = {
    ('impervious','coat') : 'Impervious Coat',
    ('ornamental', 'plastering', '12mm') : 'Ornamental Plastering 12mm',
    ('plastering', 'two','12mm') : 'Plastering 12mm Two Coats',
    ('plastering', 'two','20mm') : 'Plastering 20mm Two Coats',
    ('plastering', 'one','12mm') : 'Plastering 12mm Two Coats',
    ('plastering', 'one','20mm') : 'Plastering 20mm Two Coats',
    ('drop','wall') : 'Drop Walls',
    
    
}

painting_sub_filters = {
    ('wall','painting') : 'Wall Painting',
    ('wood','painting') : 'Wood Painting',
    ('iron','painting') : 'Iron Painting',
    ('steel','painting') : 'Iron Painting',
      
}

flooring_sub_filters = {
    ('flooring', 'granite') : 'Granite Flooring',
    ('slab', 'granite') : 'Granite Flooring',
    ('polish', 'granite') : 'Granite',
    ('concrete', 'flooring','crushed','metal') : 'Concrete Flooring with Chips',
    ('concrete', 'flooring') : 'Concrete Flooring',
    ('flooring', 'chequered', 'cement', 'tiles'):'Chequered Cement Tiles Flooring',
    ('dadooing', 'wall', 'tile'): 'Dadooing Wall Tiles',
    ('skirting', 'vitrified', 'tiles'): 'Vitrified Tiles Skirting',
    ('flooring', 'vitrified', 'tiles'): 'Vitrified Tiles Flooring',
    ('skirting', 'ceramic', 'tiles'): 'Ceramic Tiles Skirting',
    ('flooring', 'ceramic', 'tiles') : 'Ceramic Tiles Flooring',
    ('flooring', 'shahabad', 'tandur') : 'Tandur Stone Flooring',
    ('skirting', 'shahabad', 'tandur') : 'Tandur Stone Skirting',
    ('paving', 'concrete', 'blocks') : 'Concrete Blocks Paving'
    
    
}

doors_sub_filters = {
    ('door', 'wpc') : "WPC Doors",
    ('door','ply'): "PlyWood Doors"
    
}

windows_sub_filter = {
    ('window') : 'Windows'
}

ventilators_sub_filter = {
    ('ventilator') : 'Ventilators'
}

sanitary_sub_filter = {
    ('pvc','pipe') : 'PVC Pipes',
    ('cpvc','pipe') : 'CPVC Pipes',
    ('brass','bib','tap'): 'Bib Taps',
    ('swg','pipe') : 'SWG Pipes',
    ('mirror'): 'Mirrors',
    ('wash','hand','basin'):'Hand Wash Basin',
    ('soap','dish'):'Soap Dishes',
    ('wall','mixer'):'Wall Mixers',
    ('urinals'):'Urinals',
    ('european','closet'):'European Closet',
    ('orissa','closet'): 'Indian Closet',
    ('inspection','chamber'):'Inspection Chamber',
    ('manhole'):'Man Holes',
    ('man','hole'):'Man Holes',
    ('floor','trap','jali'): 'Floor Trap Jali',
    ('gully','trap'):'Gully Trap Jali'
    
    
}

# %%
tuple([x.lower() for x in "Door Double leaf Medium teak wood Frame".split()])
# Out:
# ('door', 'double', 'leaf', 'medium', 'teak', 'wood', 'frame')

# %%
cat = [
                    ['steel','fe 500']
]

[tuple(x) for x in cat]
# Out:
# [('steel', 'fe 500')]

# %%
def apply_sub_filter(description,filter_dict):
    
    for filter_list in filter_dict.keys():
#         print(filter_list)
        keyword_len = len(filter_list)
        found_count = 0
        
        for keyword in filter_list:
            if(keyword in description):
                found_count += 1
#         print("key found count:",found_count)

        if(found_count == keyword_len):
#             print(filter_dict[filter_list])
            return filter_dict[filter_list]
    return "not_filled"

# %%
def get_sub_category(row,*filters):

    filter_dict = filters[0]
    category = filters[1]
#     print(filter_dict)
    
#     print(type(description))
  
    if(row['sub_category'] == "not_filled" and row['category'] == category):

            description = row['Description'].lower()
            return apply_sub_filter(description,filter_dict)
    else:
        return row['sub_category']

# %%
def return_mask(category):
    return df['category'] == category

# %%
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[concrete_sub_filters,'Concrete'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[steel_sub_filters,'Steel'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[brick_masonry_sub_filters,'Brick Masonry'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[plastering_sub_filters,'Plastering'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[painting_sub_filters,'Painting'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[flooring_sub_filters,'Flooring'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[doors_sub_filters,'Doors'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[windows_sub_filter,'Windows'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[ventilators_sub_filter,'Ventilators'])
df['sub_category'] =  df.apply(get_sub_category,axis=1,args=[sanitary_sub_filter,'Sanitary'])

# %%
df['sub_category'].value_counts()
# Out:
# not_filled                      134
# VRCC                             32
# RCC                              18
# Mirrors                          16
# PCC                              13
# Granite Flooring                 12
# PVC Pipes                        11
# Plastering 12mm Two Coats        10
# Fly Ash Bricks                    9
# Granite                           8
# Impervious Coat                   8
# Wall Painting                     7
# PlyWood Doors                     6
# Steel                             5
# Ornamental Plastering 12mm        5
# SWG Pipes                         4
# Drop Walls                        4
# Ceramic Tiles Flooring            4
# Dadooing Wall Tiles               4
# Vitrified Tiles Skirting          4
# Vitrified Tiles Flooring          4
# Ventilators                       3
# Concrete Flooring                 2
# WPC Doors                         2
# Iron Painting                     2
# Tandur Stone Flooring             2
# Concrete Flooring with Chips      2
# Windows                           1
# Wood Painting                     1
# Cinder Concrete                   1
# VCC                               1
# Plastering 20mm Two Coats         1
# Bib Taps                          1
# Name: sub_category, dtype: int64
